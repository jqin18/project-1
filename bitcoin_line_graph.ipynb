# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import sys
import time
import datetime

from statistics import mode

import matplotlib.dates as mdates


bitcoin_path = "/Users/minoperic/Data Analytics/Project 1/Data/bitcoin_cleaned.csv"

bitcoin_df = pd.read_csv(bitcoin_path,low_memory=False)

bitcoin_df.head(10)
# Out:
#    Unnamed: 0 trade_date  trade_month  price_usd
# 0           0  01-Jan-16            1     434.33
# 1           1  02-Jan-16            1     433.44
# 2           2  03-Jan-16            1     430.01
# 3           3  04-Jan-16            1     433.09
# 4           4  05-Jan-16            1     431.96
# 5           5  06-Jan-16            1     429.11
# 6           6  07-Jan-16            1     458.05
# 7           7  08-Jan-16            1     453.23
# 8           8  09-Jan-16            1     447.61
# 9           9  10-Jan-16            1     447.99

# %%
# Generate line plot of date (x) vs. price (y)

# plot data
fig, ax = plt.subplots(figsize=(15,7))

x=bitcoin_df["trade_date"]
y=bitcoin_df["price_usd"]


# use unstack()
bitcoin= plt.plot(x,y, color="blue" )

plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.title("Yearly change of Bitcoin (Jan 2016 - Aug 2020)")
# Out:
# Text(0.5, 1.0, 'Yearly change of Bitcoin (Jan 2016 - Aug 2020)')
