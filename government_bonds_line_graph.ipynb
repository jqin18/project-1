# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import sys
import time
import datetime

from statistics import mode

import matplotlib.dates as mdates


bonds_path = "/Users/minoperic/Data Analytics/Project 1/Data/government_bonds.csv"

bonds_df = pd.read_csv(bonds_path,low_memory=False)

bonds_df.head(10)
# Out:
#   trade_date  trade_month  bond_rate
# 0   4-Jan-16            1       1.98
# 1   5-Jan-16            1       1.98
# 2   6-Jan-16            1       1.99
# 3   7-Jan-16            1       1.95
# 4   8-Jan-16            1       2.00
# 5  11-Jan-16            1       1.98
# 6  12-Jan-16            1       2.00
# 7  13-Jan-16            1       1.99
# 8  14-Jan-16            1       1.95
# 9  15-Jan-16            1       1.95

# %%
# Generate line plot of date (x) vs. price (y)

# plot data
fig, ax = plt.subplots(figsize=(15,7))

x=bonds_df["trade_date"]
y=bonds_df["bond_rate"]


# use unstack()
bitcoin= plt.plot(x,y, color="red" )

plt.xlabel("Date")
plt.ylabel("Interest Rate (2 Year Yield)")
plt.title("Yearly change of RBA Government Bond Rate - 2 Year Yield (Jan 2016 - Aug 2020)")
# Out:
# Text(0.5, 1.0, 'Yearly change of RBA Government Bond Rate - 2 Year Yield (Jan 2016 - Aug 2020)')
